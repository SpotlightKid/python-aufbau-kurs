# %% [markdown]
# # Tag 3

# %%
print("Guten Morgen!")

# %% [markdown]
# ## Links zu Flask und Formularen
#
# * [Awesome Flask](https://github.com/humiaozuzu/awesome-flask) - A curated list of awesome Flask resources and plugins
# * [Flask-WTF](https://flask-wtf.readthedocs.io/) - Simple integration of Flask and WTForms, including CSRF, file upload, and reCAPTCHA.
# * [The Flask Mega-Tutorial, Part III: Web Forms](https://blog.miguelgrinberg.com/post/the-flask-mega-tutorial-part-iii-web-forms)
# * [Dynamic Forms with Flask](https://blog.miguelgrinberg.com/post/dynamic-forms-with-flask)

# %% [markdown]
# ## `requests`
#
# ```bash
# PS C:\Users\Admin\Documents\python-aufbau-kurs> python -m pip install requests
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.2 idna-3.10 requests-2.32.3 urllib3-2.4.0
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ```

# %%
import requests

dir(requests)

response = requests.get("https://softed.de")
repr(response)
dir(response)
print(response.status_code)
print(response.url)
print(response.reason)
repr(response.raw)
print(response.text)
try:
     resp = requests.get("https://google.com")
except requests.HTTPError:
    print("Hat nich geklappt.")

if resp.status_code == 200:
    print(resp.text)

resp = requests.get('https://dummyjson.com/test')
print(resp.status_code)
print(resp.text)
print(type(resp.text))
data1 = resp.json()
print(data1)
print(type(data1))
import json
data2 = json.loads(resp.text)
data1 == data2
print(type(data2))

# %% [markdown]
# # Context Managers
#
# ```python
# >>> with open("urls.txt") as f:
# ...     f.read()
# ...
# 'https://www.google.com\nhttps://www.python.org\nhttps://www.wikipedia.org\n'
# >>> f
# <_io.TextIOWrapper name='urls.txt' mode='r' encoding='cp1252'>
# >>> f.closed
# True
# ```

# %% [markdown]
# ## Walrus Operator (Zuweisung als Ausdruck)
#
# Beispiel:
#
# ```python
# from urllib.parse import urlparse
#
# urls = [
#     "https://softed.de",
#     "https://google.com/?q=Python",
#     "ftp://example.com/",
# ]
# non_google_urls = [
#     host for u in urls
#     if (host := urlparse(u).hostname) != "google.com"
# ]
# ```

# %% [markdown]
# - wheel paket bauen ("hatch build")
# - venv erstellen
# - venv aktivieren
# - wheel paket in venv installieren ("pip install dist/*.whl")
# - python interactiven modus starten
# - `import csvreader`
# - `dir(csvreader)`

# %% [markdown]
# ## Packaging
#
# ```
# PS C:\Users\Admin\Documents\python-aufbau-kurs> cd .\loesungen\
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen> python -m hatch new -i
# Project name: csvreader
# Description []: A simple CSV reader module
#
# csvreader
# ├── src
# │   └── csvreader
# │       ├── __about__.py
# │       └── __init__.py
# ├── tests
# │   └── __init__.py
# ├── LICENSE.txt
# ├── README.md
# └── pyproject.toml
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen> cd .\csvreader\
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\csvreader> dir
#
#
#     Verzeichnis: C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\csvreader
#
#
# Mode                 LastWriteTime         Length Name
# ----                 -------------         ------ ----
# d-----        28.05.2025     15:00                src
# d-----        28.05.2025     15:00                tests
# -a----        28.05.2025     15:00           1113 LICENSE.txt
# -a----        28.05.2025     15:00           1646 pyproject.toml
# -a----        28.05.2025     15:00            505 README.md
#
#
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\csvreader> cd ..
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen> mv .\csvreader\ .\6_packaging\
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen> cd .\6_packaging\csvreader\
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> pytest
# ============================================================================================= test session starts =============================================================================================
# platform win32 -- Python 3.13.0, pytest-8.3.5, pluggy-1.6.0
# rootdir: C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader
# configfile: pyproject.toml
# plugins: anyio-4.9.0
# collected 0 items / 1 error
#
# =================================================================================================== ERRORS ====================================================================================================
# __________________________________________________________________________________ ERROR collecting tests/test_csvreader.py ___________________________________________________________________________________
# ImportError while importing test module 'C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader\tests\test_csvreader.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# C:\Program Files\Python313\Lib\importlib\__init__.py:88: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# tests\test_csvreader.py:2: in <module>
#     from csvreader import CSVReader
# E   ModuleNotFoundError: No module named 'csvreader'
# =========================================================================================== short test summary info ===========================================================================================
# ERROR tests/test_csvreader.py
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!! Interrupted: 1 error during collection !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ============================================================================================== 1 error in 0.33s ===============================================================================================
# ```
#
# Vor dem nächsten Schritt folgende Sektion zu `pyproject.toml` hinzufügen:
#
# ```
# [tool.pytest.ini_options]
# pythonpath = [
#   "src"
# ]
# ```
#
# ```
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> pytest
# ============================================================================================= test session starts =============================================================================================
# platform win32 -- Python 3.13.0, pytest-8.3.5, pluggy-1.6.0
# rootdir: C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader
# configfile: pyproject.toml
# plugins: anyio-4.9.0
# collected 3 items
#
# tests\test_csvreader.py ...                                                                                                                                                                              [100%]
#
# ============================================================================================== 3 passed in 0.17s ==============================================================================================
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> pytest
# ============================================================================================= test session starts =============================================================================================
# platform win32 -- Python 3.13.0, pytest-8.3.5, pluggy-1.6.0
# rootdir: C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader
# configfile: pyproject.toml
# plugins: anyio-4.9.0
# collected 3 items
#
# tests\test_csvreader.py ...                                                                                                                                                                              [100%]
#
# ============================================================================================== 3 passed in 0.13s ==============================================================================================
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> hatch build
# ──────────────────────────────────────────────────────────────────────────────────────────────────── sdist ─────────────────────────────────────────────────────────────────────────────────────────────────────
# dist\csvreader-0.0.1.tar.gz
# ──────────────────────────────────────────────────────────────────────────────────────────────────── wheel ─────────────────────────────────────────────────────────────────────────────────────────────────────
# dist\csvreader-0.0.1-py3-none-any.whl
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> python -m venv venv
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> python -m pip install .\dist\csvreader-0.0.1-py3-none-any.whl
# Processing c:\users\admin\documents\python-aufbau-kurs\loesungen\6_packaging\csvreader\dist\csvreader-0.0.1-py3-none-any.whl
# Installing collected packages: csvreader
# Successfully installed csvreader-0.0.1
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# PS C:\Users\Admin\Documents\python-aufbau-kurs\loesungen\6_packaging\csvreader> python
# Python 3.13.0 (tags/v3.13.0:60403a5, Oct  7 2024, 09:38:07) [MSC v.1941 64 bit (AMD64)] on win32
# Type "help", "copyright", "credits" or "license" for more information.
# >>> import csvreader
# >>> dir()
# ['__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'csvreader']
# >>> dir(csvreader)
# ['CSVReader', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']
# >>> reader = csvreader.CSVReader([])
# ```
